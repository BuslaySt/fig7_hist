# %% [markdown]
# <a href="https://colab.research.google.com/github/BuslaySt/fig7_hist/blob/main/Fig7histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
In [1]: %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
piclink = "https://github.com/BuslaySt/fig7_hist/blob/main/Fig7t.png?raw=true"
img = mpimg.imread(piclink)
imgplot = plt.imshow(img)
# plt.axis('off')  # clear x-axis and y-axis

# %%
RED = [255, 0, 0]
ORANGE = [255, 128, 0]
YELLOW = [255, 255, 0]
GREEN = [0, 255, 0]
LIGHTBLUE = [0, 255, 255]
BLUE = [0, 0, 255]
VIOLET = [255, 0, 255]

# %%
rgb_image = []
line = []
colors = [0, 0, 0, 0, 0, 0, 0]
clrarray = []
for row in img:
  for col in row:
    r, g, b = col
    if 1.0 >= r >= 0.3:
      if 0.0 <= b <= 0.5:
        if 0.0 <= g <= 0.5:
          pixel = RED
          colors[0] += 1
          clrarray.append(1300)
        elif 0.5 < g <= 0.99:
          pixel = ORANGE
          colors[1] += 1
          clrarray.append(1305)
        else:
          pixel = YELLOW
          colors[2] += 1
          clrarray.append(1310)
      else:
        pixel = VIOLET
        colors[6] += 1
        clrarray.append(1328)
    elif 0.5 > r >= 0.0:
      if 1.0 >= g >= 0.5:
        if 0.0 <= b <= 0.8:
          pixel = GREEN
          colors[3] += 1
          clrarray.append(1315)
        else:
          pixel = LIGHTBLUE
          clrarray.append(1320)
          colors[4] += 1
      else:
        pixel = BLUE
        colors[5] += 1
        clrarray.append(1325)
    line.append(pixel)
  rgb_image.append(line)
  line = []

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1423.5, 1427.5, -0.5)

# %%
plt.imshow(rgb_image)
plt.axis('off')
# Out:
# (-0.5, 1423.5, 1427.5, -0.5)

# %%
x = [1300, 1305, 1310, 1315, 1320, 1325, 1328]

# %%
result = plt.hist(clrarray, bins = x)

# %%
result
# Out:
# (array([  2473.,  23726., 129223., 751998., 836083., 289969.]),
#  array([1300, 1305, 1310, 1315, 1320, 1325, 1328]),
#  <a list of 6 Patch objects>)
